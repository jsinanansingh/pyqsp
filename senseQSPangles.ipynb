# %%
from pyqsp.angle_sequence import QuantumSignalProcessingPhases
from pyqsp.poly import PolyRect
import numpy as np
from pyqsp.response import PlotQSPResponse
from scipy.special import eval_chebyt as chebyt

# %%
ang_seq = QuantumSignalProcessingPhases([0,-1/3, 0, 4/3], signal_operator="Wx")
print(ang_seq)
# Out:
# [-1.332057685464075, 0.55165979289707, 0.5516597928970705, 0.23873864133082187]

# %%
PlotQSPResponse(ang_seq,signal_operator="Wx")

# %%
ang_seq=[0,np.arccos(-1/3), -np.arccos(-1/3),0]
PlotQSPResponse(ang_seq,signal_operator="Wx")
